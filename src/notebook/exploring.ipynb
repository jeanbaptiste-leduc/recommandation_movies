# %%
import sys
from pathlib import Path

project_root = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film")
sys.path.insert(0, str(project_root / "src"))

# %%
from pathlib import Path
from cinema_de_la_cite.data.load_csv import load_csv

# chemin vers ton CSV (à adapter selon ton arborescence)
csv_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\row\tmdb_full.csv")

df = load_csv(csv_path)
df
# Out:
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\load_csv.py:23: SyntaxWarning: invalid escape sequence '\D'
#   """
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\load_csv.py:21: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
#         adult                     backdrop_path  budget  \
# 0       False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1       False                               NaN       0
# 2       False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3       False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4       False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
# ...       ...                               ...     ...
# 309567  False  /oGW8uF821i8VowzpmECbxk7QXNs.jpg       0
# 309568  False  /oQ429AcD85ttxvOxAaYpETnAsW0.jpg       0
# 309569  False  /fJhruCWu4sx3TKhFigEVntiVL93.jpg       0
# ...

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'production_companies_name',
#        'production_companies_country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309572 entries, 0 to 309571
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         309572 non-null  bool
#  1   backdrop_path                 151760 non-null  object
#  2   budget                        309572 non-null  int64
#  3   genres                        309572 non-null  object
#  4   homepage                      44262 non-null   object
#  5   id                            309572 non-null  int64
#  6   imdb_id                       309572 non-null  object
#  7   original_language             309572 non-null  object
#  8   original_title                309572 non-null  object
#  9   overview                      282512 non-null  object
#  10  popularity                    309572 non-null  float64
#  11  poster_path                   264159 non-null  object
# ...

# %%
df_final = df_filtered[df_filtered["genres"] != "TV Movie"]
df_final
# Out:
#         adult                     backdrop_path  budget  \
# 2       False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 76      False  /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg       0
# 77      False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg       0
# 78      False  /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg       0
# 112     False  /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg       0
# ...       ...                               ...     ...
# 308577  False                               NaN       0
# 309030  False                               NaN       0
# 309102  False                               NaN       0
# 309264  False                               NaN       0
# 309387  False  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg       0
#
#                                  genres homepage      id    imdb_id  \
# 2                  ['Drama', 'Romance']      NaN    8773  tt0055747
# 76                            ['Drama']      NaN     108  tt0108394
# 77       ['Comedy', 'Drama', 'Mystery']      NaN     109  tt0111507
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6531 entries, 2 to 309387
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         6531 non-null   bool
#  1   backdrop_path                 4815 non-null   object
#  2   budget                        6531 non-null   int64
#  3   genres                        6531 non-null   object
#  4   homepage                      638 non-null    object
#  5   id                            6531 non-null   int64
#  6   imdb_id                       6531 non-null   object
#  7   original_language             6531 non-null   object
#  8   original_title                6531 non-null   object
#  9   overview                      5802 non-null   object
#  10  popularity                    6531 non-null   float64
#  11  poster_path                   6283 non-null   object
# ...

# %%
from cinema_de_la_cite.data.first_clean import clean_movies
csv_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\row\tmdb_full.csv")
df_clean = clean_movies(csv_path)
df_clean
# Out:
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\load_csv.py:21: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
#         adult                     backdrop_path  budget  \
# 2       False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 76      False  /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg       0
# 77      False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg       0
# 78      False  /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg       0
# 112     False  /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg       0
# ...       ...                               ...     ...
# 308577  False                               NaN       0
# 309030  False                               NaN       0
# 309102  False                               NaN       0
# 309264  False                               NaN       0
# 309387  False  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg       0
#
#                                  genres homepage      id    imdb_id  \
# ...

# %%
from cinema_de_la_cite.data.first_clean import clean_movies
from cinema_de_la_cite.data.save_dataframe_to_csv import save_dataframe_clean
from pathlib import Path

project_root = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film")
df_clean = clean_movies(project_root / "data/row/tmdb_full.csv")

save_dataframe_clean(df_clean, "tmdb_selected.csv", project_root)
# Out:
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\first_clean.py:32: SyntaxWarning: invalid escape sequence '\D'
#   """
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\save_dataframe_to_csv.py:24: SyntaxWarning: invalid escape sequence '\D'
#   """
# F:\DataAnalystSimplon\Projet_recommandation_film\src\cinema_de_la_cite\data\load_csv.py:21: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)

# %%
from cinema_de_la_cite.data.load_csv import load_csv
csv_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\clean\tmdb_selected.csv")

df = load_csv(csv_path)
df
# Out:
#       adult                     backdrop_path  budget  \
# 0     False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 1     False  /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg       0
# 2     False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg       0
# 3     False  /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg       0
# 4     False  /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg       0
# ...     ...                               ...     ...
# 6526  False                               NaN       0
# 6527  False                               NaN       0
# 6528  False                               NaN       0
# 6529  False                               NaN       0
# 6530  False  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg       0
#
#                                genres homepage      id    imdb_id  \
# 0                ['Drama', 'Romance']      NaN    8773  tt0055747
# 1                           ['Drama']      NaN     108  tt0108394
# 2      ['Comedy', 'Drama', 'Mystery']      NaN     109  tt0111507
# ...
