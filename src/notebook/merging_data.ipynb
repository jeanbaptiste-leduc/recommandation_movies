# %%
import duckdb
import pandas as pd
import sys
from pathlib import Path

project_root = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film")
sys.path.insert(0, str(project_root / "src"))

csv_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\clean\tmdb_final.csv")
name_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\row\name.basics.tsv")
crew_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\row\title.crew.tsv")
title_path = Path(r"F:\DataAnalystSimplon\Projet_recommandation_film\data\row\title.principals.tsv")

# %%
movies = pd.read_csv(csv_path)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6200 entries, 0 to 6199
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   backdrop_path                      4676 non-null   object
#  1   id                                 6200 non-null   int64
#  2   imdb_id                            6200 non-null   object
#  3   original_language                  6200 non-null   object
#  4   original_title                     6200 non-null   object
#  5   overview                           6200 non-null   object
#  6   poster_path                        6200 non-null   object
#  7   release_date                       6200 non-null   object
#  8   runtime                            6200 non-null   int64
#  9   title                              6200 non-null   object
#  10  video                              6200 non-null   bool
#  11  vote_average                       6200 non-null   float64
#  12  vote_count                         6200 non-null   int64
#  13  year                               6200 non-null   int64
#  14  decade                             6200 non-null   int64
#  15  genres_list                        6200 non-null   object
#  16  production_companies_name_list     6200 non-null   object
#  17  production_countries_list          6200 non-null   object
#  18  production_companies_country_list  6200 non-null   object
#  19  spoken_languages_list              6200 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(13)
# memory usage: 926.5+ KB

# %%
# Connexion DuckDB
con = duckdb.connect(database=':memory:')

# Créer les tables
con.execute(f"CREATE TABLE crew AS SELECT * FROM read_csv_auto('{crew_path}', delim='\t', nullstr='\\N')")
con.execute(f"CREATE TABLE principals AS SELECT * FROM read_csv_auto('{title_path}', delim='\t', nullstr='\\N')")
con.execute(f"CREATE TABLE names AS SELECT * FROM read_csv_auto('{name_path}', delim='\t', nullstr='\\N')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
tconst_list = movies['imdb_id'].tolist()

# %%
con.execute("DROP TABLE IF EXISTS crew_filtered")
con.execute("DROP TABLE IF EXISTS principals_filtered")
con.execute("DROP TABLE IF EXISTS crew_named")
con.execute("DROP TABLE IF EXISTS actors_named")

# %%
con.execute(f"""
    CREATE TABLE crew_filtered AS
    SELECT * FROM crew
    WHERE tconst IN ({','.join([f"'{t}'" for t in tconst_list])})
""").df()
# Out:
#    Count
# 0   6189

# %%
con.execute(f"""
    CREATE TABLE principals_filtered AS
    SELECT * FROM principals
    WHERE tconst IN ({','.join([f"'{t}'" for t in tconst_list])})
""").df()
# Out:
#     Count
# 0  103114

# %%
# Joindre avec names pour avoir les noms réels
con.execute("""
    CREATE TABLE crew_named AS
    SELECT 
        c.tconst,
        CASE WHEN c.directors='\\N' THEN '' ELSE c.directors END AS directors,
        CASE WHEN c.writers='\\N' THEN '' ELSE c.writers END AS writers
    FROM crew_filtered c
""").df()
# Out:
#    Count
# 0   6189

# %%
con.execute("""
    CREATE TABLE actors_named AS
    SELECT 
        p.tconst, 
        n.primaryName AS actor_name,
        p.category
    FROM principals_filtered p
    LEFT JOIN names n
    ON p.nconst = n.nconst
    WHERE p.category IN ('actor','actress')
""").df()
# Out:
#    Count
# 0  46826

# %%
# Directors et writers sous forme de liste
crew_lists = con.execute("""
    SELECT tconst,
           split(directors, ',') AS director_list,
           split(writers, ',') AS writer_list
    FROM crew_named
""").df()

# Acteurs sous forme de liste
actors_lists = con.execute("""
    SELECT tconst,
           list(actor_name) AS actor_list
    FROM actors_named
    GROUP BY tconst
""").df()

# %%
print(crew_lists)
# Out:
#          tconst                                      director_list  \
# 0     tt0961097                                        [nm0074426]
# 1     tt0962782                                        [nm0069342]
# 2     tt0963989                                        [nm0415245]
# 3     tt0969701                                        [nm0494504]
# 4     tt0973844  [nm0000766, nm0000801, nm0000806, nm0001005, n...
# ...         ...                                                ...
# 6184  tt9369620                             [nm8263214, nm8441994]
# 6185  tt9372054                                        [nm0084485]
# 6186  tt9408232                                        [nm4766133]
# 6187  tt9430820                                        [nm3251986]
# 6188  tt9437598  [nm10326714, nm10326715, nm10326716, nm1032671...
#
#                                             writer_list
# 0                                [nm0443592, nm0074426]
# 1                     [nm6570587, nm0069342, nm0603294]
# 2                                           [nm0415245]
# 3                                           [nm0494504]
# 4     [nm0210701, nm0000382, nm0000801, nm0000806, n...
# ...                                                 ...
# 6184                             [nm8263214, nm8441994]
# 6185                                               <NA>
# 6186                                        [nm4766133]
# 6187                                               <NA>
# 6188                                               <NA>
#
# [6189 rows x 3 columns]

# %%
print(actors_lists)
# Out:
#           tconst                                         actor_list
# 0      tt0035515  [Gisèle Pascal, Jean Parédès, André Roussin, L...
# 1      tt0064327  [Jean Parédès, Bernadette Lafont, Francis Lax,...
# 2      tt0034471  [Gisèle Pascal, Henri Poupon, Raimu, Louis Jou...
# 3      tt0207724  [Lucien Pascal, Marcel Pérès, Roger Saget, Ode...
# 4      tt0167000  [Gisèle Pascal, Simone Renant, Germaine Ledoye...
# ...          ...                                                ...
# 5268  tt10655822  [Louise Massin, Mona Behr, Benjamin Siksou, Ga...
# 5269   tt5821240                 [Ines Le Poullennec, Dylan Pedron]
# 5270   tt0176958                         [Muriel Simon, Joel Simon]
# 5271   tt0132649                            [Marie-Anne Malleville]
# 5272   tt5082718                              [Stéphane Ronchewski]
#
# [5273 rows x 2 columns]

# %%
# 1) Directors : explode, join names, re-aggregate en array de noms
con.execute("""
CREATE OR REPLACE TABLE directors_named AS
SELECT
    tconst,
    array_agg(COALESCE(n.primaryName, s.nconst) ORDER BY 1) AS director_names
FROM (
    SELECT
        tconst,
        trim(replace(replace(u.nconst_raw, '[', ''), ']', '')) AS nconst
    FROM crew_named,
         UNNEST(split(replace(replace(directors,'[',''),']',''), ',')) AS u(nconst_raw)
) AS s
LEFT JOIN names n ON s.nconst = n.nconst
GROUP BY tconst;
""")

# 2) Writers : même logique
con.execute("""
CREATE OR REPLACE TABLE writers_named AS
SELECT
    tconst,
    array_agg(COALESCE(n.primaryName, s.nconst) ORDER BY 1) AS writer_names
FROM (
    SELECT
        tconst,
        trim(replace(replace(u.nconst_raw, '[', ''), ']', '')) AS nconst
    FROM crew_named,
         UNNEST(split(replace(replace(writers,'[',''),']',''), ',')) AS u(nconst_raw)
) AS s
LEFT JOIN names n ON s.nconst = n.nconst
GROUP BY tconst;
""")

# %%
# Directors
directors_df = con.execute("SELECT * FROM directors_named").df()
print(directors_df)

# Writers
writers_df = con.execute("SELECT * FROM writers_named").df()
print(writers_df)
# Out:
#           tconst                             director_names
# 0      tt3674140     [Wim Wenders, Juliano Ribeiro Salgado]
# 1      tt0021312  [Sergei Eisenstein, Grigoriy Aleksandrov]
# 2      tt0097884                              [Louis Malle]
# 3      tt3716530                           [Paul Verhoeven]
# 4      tt0092593                              [Louis Malle]
# ...          ...                                        ...
# 6168   tt4228810                           [Vincent Garenq]
# 6169  tt13460024                           [Thierry Berrod]
# 6170  tt11349900                              [Chloé Mazlo]
# 6171   tt5196472                             [Morgan Simon]
# 6172   tt3985394                              [Laurence Ly]
#
# [6173 rows x 2 columns]
#           tconst                                       writer_names
# 0      tt0421974  [Gérard Pirès, Gilles Malençon, Albert Uderzo,...
# 1      tt0082269  [Jean-Jacques Beineix, Daniel Odier, Jean Van ...
# 2     tt14851374                             [Charlotte Gainsbourg]
# 3      tt0046149  [Yves Allégret, Jean Aurenche, Pierre Bost, Jé...
# 4      tt8792898                [Romane Bohringer, Philippe Rebbot]
# ...          ...                                                ...
# 5612   tt1847731                                   [Céline Sciamma]
# 5613   tt8053490                                [Bojina Panayotova]
# 5614   tt4333662                                      [Andy Morgan]
# 5615   tt4471456                   [Elsa Marpeau, Mathieu Missoffe]
# 5616   tt7057890                                  [Lucrèce Andreae]
#
# [5617 rows x 2 columns]

# %%
movies = movies.merge(actors_lists, left_on='imdb_id', right_on='tconst', how='left').drop(columns='tconst')
movies
# Out:
#                          backdrop_path      id    imdb_id original_language  \
# 0     /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg    8773  tt0055747                fr
# 1     /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg     108  tt0108394                fr
# 2     /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg     109  tt0111507                fr
# 3     /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg     110  tt0111495                fr
# 4     /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg     147  tt0053198                fr
# ...                                ...     ...        ...               ...
# 6195                               NaN  228590  tt0197505                fr
# 6196                               NaN  228655  tt2007418                fr
# 6197                               NaN  231154  tt1982764                fr
# 6198                               NaN  232151  tt0268168                fr
# 6199  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg  232709  tt0000495                fr
#
#                             original_title  \
# 0                      L'Amour à vingt ans
# 1                    Trois couleurs : Bleu
# 2                   Trois couleurs : Blanc
# 3                   Trois couleurs : Rouge
# 4                   Les Quatre Cents Coups
# ...                                    ...
# 6195                                  Gala
# 6196  Les trois disparitions de Soad Hosni
# 6197                  Le repas fantastique
# 6198          Le bain des dames de la cour
# 6199                  Le pêcheur de perles
#
#                                                overview  \
# 0     Love at Twenty unites five directors from five...
# 1     Julie is haunted by her grief after living thr...
# 2     Polish immigrant Karol Karol finds himself out...
# 3     Valentine, a student model in Geneva, struggle...
# 4     For young Parisian boy Antoine Doinel, life is...
# ...                                                 ...
# 6195  Gala (1961), a more polished version of Pourvu...
# 6196  This haunting and beautifully formed documenta...
# 6197  A gentleman having lunch at a hostelry experie...
# 6198  Through an invisible keyhole, the viewer peeps...
# 6199  Captivated by a vision of beckoning women, a m...
#
#                            poster_path release_date  runtime  \
# 0     /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg   1962-06-22      110
# 1     /33wsWxzsNstI8N7dvuwzFmj1qBd.jpg   1993-08-01       98
# 2     /fdIet3NSa27gobMbaUml66oCQNT.jpg   1994-01-26       92
# 3      /JHmsBiX1tjCKqAul1lzC20WcAW.jpg   1994-05-12      100
# 4     /12PuU23kkDLvTd0nb8hMlE3oShB.jpg   1959-06-03       99
# ...                                ...          ...      ...
# 6195  /fZ6jgGNN5gVDVn3M7F0QP5spfuP.jpg   1961-01-01       20
# 6196  /ttVoObIPbqBflOguONw9Dm6w1qa.jpg   2011-07-10       70
# 6197  /uD8Bgyo3kIaUHUUPU5PgMsZY4Wv.jpg   1903-01-18        2
# 6198  /vBXTVwKN0FmCzW8R1gvnJCqnmM3.jpg   1904-10-01        1
# 6199  /lK0sWgOVkzhmGhzT652wdR2l33G.jpg   1907-11-03       12
#
#                                        title  ...  vote_average  vote_count  \
# 0                             Love at Twenty  ...         6.700          41
# 1                         Three Colors: Blue  ...         7.700        1421
# 2                        Three Colors: White  ...         7.482         989
# 3                          Three Colors: Red  ...         7.957        1160
# 4                              The 400 Blows  ...         8.071        1843
# ...                                      ...  ...           ...         ...
# 6195                                    Gala  ...         6.100           7
# 6196  The Three Disappearances of Soad Hosni  ...         6.000           1
# 6197                    Le repas fantastique  ...         6.000           2
# 6198                    Court Ladies Bathing  ...         6.375           8
# 6199                     The Pearl Fisherman  ...         6.500           6
#
#       year  decade                      genres_list  \
# 0     1962    1960             ['Drama', 'Romance']
# 1     1993    1990                        ['Drama']
# 2     1994    1990   ['Comedy', 'Drama', 'Mystery']
# 3     1994    1990  ['Drama', 'Mystery', 'Romance']
# 4     1959    1950                        ['Drama']
# ...    ...     ...                              ...
# 6195  1961    1960                               []
# 6196  2011    2010                  ['Documentary']
# 6197  1903    1900            ['Comedy', 'Fantasy']
# 6198  1904    1900                               []
# 6199  1907    1900                      ['Fantasy']
#
#                          production_companies_name_list  \
# 0     ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 1     ['France 3 Cinéma', 'CED Productions', 'Miramax']
# 2     ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 3     ['Zespół Filmowy TOR', 'Le Studio Canal+', 'Fr...
# 4        ['Les Films du Carrosse', 'Sédif Productions']
# ...                                                 ...
# 6195                                                 []
# 6196    ['Joun Films', 'Sharjah Art Foundation', 'CNC']
# 6197                                ['Société Lumière']
# 6198                                   ['Pathé Frères']
# 6199                                   ['Pathé Frères']
#
#            production_countries_list       production_companies_country_list  \
# 0     ['DE', 'FR', 'IT', 'JP', 'PL']  ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']
# 1                 ['FR', 'PL', 'CH']                        ['FR', '', 'US']
# 2                       ['FR', 'PL']                ['FR', 'FR', 'FR', 'US']
# 3                 ['FR', 'PL', 'CH']                ['PL', 'FR', 'FR', 'CH']
# 4                             ['FR']                            ['FR', 'FR']
# ...                              ...                                     ...
# 6195                              []                                      []
# 6196              ['FR', 'LB', 'AE']                                      []
# 6197                          ['FR']                                      []
# 6198                          ['FR']                                      []
# 6199                          ['FR']                                      []
#
#                spoken_languages_list  \
# 0     ['it', 'ja', 'pl', 'fr', 'de']
# 1                       ['fr', 'pl']
# 2                 ['fr', 'hu', 'pl']
# 3                             ['fr']
# 4                       ['en', 'fr']
# ...                              ...
# 6195                              []
# 6196              ['ar', 'en', 'fr']
# 6197                          ['xx']
# 6198                          ['xx']
# 6199                          ['xx']
#
#                                              actor_list
# 0     [Marie-France Pisier, Eleonora Rossi Drago, Ch...
# 1     [Florence Pernel, Hugues Quester, Benoît Régen...
# 2     [Cezary Pazura, Jerzy Nowak, Zbigniew Zamachow...
# 3     [Jean Schlegel, Elzbieta Jasinska, Samuel Le B...
# 4     [Albert Rémy, Richard Kanayan, Daniel Couturie...
# ...                                                 ...
# 6195  [Claude Melki, Gésip Légitimus, Dolly Bell, Ge...
# 6196                                                NaN
# 6197                                                NaN
# 6198                                                NaN
# 6199                                                NaN
#
# [6200 rows x 21 columns]

# %%
movies = movies.merge(directors_df, left_on='imdb_id', right_on='tconst', how='left').drop(columns='tconst')
movies
# Out:
#                          backdrop_path      id    imdb_id original_language  \
# 0     /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg    8773  tt0055747                fr
# 1     /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg     108  tt0108394                fr
# 2     /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg     109  tt0111507                fr
# 3     /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg     110  tt0111495                fr
# 4     /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg     147  tt0053198                fr
# ...                                ...     ...        ...               ...
# 6195                               NaN  228590  tt0197505                fr
# 6196                               NaN  228655  tt2007418                fr
# 6197                               NaN  231154  tt1982764                fr
# 6198                               NaN  232151  tt0268168                fr
# 6199  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg  232709  tt0000495                fr
#
#                             original_title  \
# 0                      L'Amour à vingt ans
# 1                    Trois couleurs : Bleu
# 2                   Trois couleurs : Blanc
# 3                   Trois couleurs : Rouge
# 4                   Les Quatre Cents Coups
# ...                                    ...
# 6195                                  Gala
# 6196  Les trois disparitions de Soad Hosni
# 6197                  Le repas fantastique
# 6198          Le bain des dames de la cour
# 6199                  Le pêcheur de perles
#
#                                                overview  \
# 0     Love at Twenty unites five directors from five...
# 1     Julie is haunted by her grief after living thr...
# 2     Polish immigrant Karol Karol finds himself out...
# 3     Valentine, a student model in Geneva, struggle...
# 4     For young Parisian boy Antoine Doinel, life is...
# ...                                                 ...
# 6195  Gala (1961), a more polished version of Pourvu...
# 6196  This haunting and beautifully formed documenta...
# 6197  A gentleman having lunch at a hostelry experie...
# 6198  Through an invisible keyhole, the viewer peeps...
# 6199  Captivated by a vision of beckoning women, a m...
#
#                            poster_path release_date  runtime  \
# 0     /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg   1962-06-22      110
# 1     /33wsWxzsNstI8N7dvuwzFmj1qBd.jpg   1993-08-01       98
# 2     /fdIet3NSa27gobMbaUml66oCQNT.jpg   1994-01-26       92
# 3      /JHmsBiX1tjCKqAul1lzC20WcAW.jpg   1994-05-12      100
# 4     /12PuU23kkDLvTd0nb8hMlE3oShB.jpg   1959-06-03       99
# ...                                ...          ...      ...
# 6195  /fZ6jgGNN5gVDVn3M7F0QP5spfuP.jpg   1961-01-01       20
# 6196  /ttVoObIPbqBflOguONw9Dm6w1qa.jpg   2011-07-10       70
# 6197  /uD8Bgyo3kIaUHUUPU5PgMsZY4Wv.jpg   1903-01-18        2
# 6198  /vBXTVwKN0FmCzW8R1gvnJCqnmM3.jpg   1904-10-01        1
# 6199  /lK0sWgOVkzhmGhzT652wdR2l33G.jpg   1907-11-03       12
#
#                                        title  ...  vote_count  year  decade  \
# 0                             Love at Twenty  ...          41  1962    1960
# 1                         Three Colors: Blue  ...        1421  1993    1990
# 2                        Three Colors: White  ...         989  1994    1990
# 3                          Three Colors: Red  ...        1160  1994    1990
# 4                              The 400 Blows  ...        1843  1959    1950
# ...                                      ...  ...         ...   ...     ...
# 6195                                    Gala  ...           7  1961    1960
# 6196  The Three Disappearances of Soad Hosni  ...           1  2011    2010
# 6197                    Le repas fantastique  ...           2  1903    1900
# 6198                    Court Ladies Bathing  ...           8  1904    1900
# 6199                     The Pearl Fisherman  ...           6  1907    1900
#
#                           genres_list  \
# 0                ['Drama', 'Romance']
# 1                           ['Drama']
# 2      ['Comedy', 'Drama', 'Mystery']
# 3     ['Drama', 'Mystery', 'Romance']
# 4                           ['Drama']
# ...                               ...
# 6195                               []
# 6196                  ['Documentary']
# 6197            ['Comedy', 'Fantasy']
# 6198                               []
# 6199                      ['Fantasy']
#
#                          production_companies_name_list  \
# 0     ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 1     ['France 3 Cinéma', 'CED Productions', 'Miramax']
# 2     ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 3     ['Zespół Filmowy TOR', 'Le Studio Canal+', 'Fr...
# 4        ['Les Films du Carrosse', 'Sédif Productions']
# ...                                                 ...
# 6195                                                 []
# 6196    ['Joun Films', 'Sharjah Art Foundation', 'CNC']
# 6197                                ['Société Lumière']
# 6198                                   ['Pathé Frères']
# 6199                                   ['Pathé Frères']
#
#            production_countries_list       production_companies_country_list  \
# 0     ['DE', 'FR', 'IT', 'JP', 'PL']  ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']
# 1                 ['FR', 'PL', 'CH']                        ['FR', '', 'US']
# 2                       ['FR', 'PL']                ['FR', 'FR', 'FR', 'US']
# 3                 ['FR', 'PL', 'CH']                ['PL', 'FR', 'FR', 'CH']
# 4                             ['FR']                            ['FR', 'FR']
# ...                              ...                                     ...
# 6195                              []                                      []
# 6196              ['FR', 'LB', 'AE']                                      []
# 6197                          ['FR']                                      []
# 6198                          ['FR']                                      []
# 6199                          ['FR']                                      []
#
#                spoken_languages_list  \
# 0     ['it', 'ja', 'pl', 'fr', 'de']
# 1                       ['fr', 'pl']
# 2                 ['fr', 'hu', 'pl']
# 3                             ['fr']
# 4                       ['en', 'fr']
# ...                              ...
# 6195                              []
# 6196              ['ar', 'en', 'fr']
# 6197                          ['xx']
# 6198                          ['xx']
# 6199                          ['xx']
#
#                                              actor_list  \
# 0     [Marie-France Pisier, Eleonora Rossi Drago, Ch...
# 1     [Florence Pernel, Hugues Quester, Benoît Régen...
# 2     [Cezary Pazura, Jerzy Nowak, Zbigniew Zamachow...
# 3     [Jean Schlegel, Elzbieta Jasinska, Samuel Le B...
# 4     [Albert Rémy, Richard Kanayan, Daniel Couturie...
# ...                                                 ...
# 6195  [Claude Melki, Gésip Légitimus, Dolly Bell, Ge...
# 6196                                                NaN
# 6197                                                NaN
# 6198                                                NaN
# 6199                                                NaN
#
#                                          director_names
# 0     [François Truffaut, Marcel Ophüls, Shintarô Is...
# 1                                [Krzysztof Kieslowski]
# 2                                [Krzysztof Kieslowski]
# 3                                [Krzysztof Kieslowski]
# 4                                   [François Truffaut]
# ...                                                 ...
# 6195                               [Jean-Daniel Pollet]
# 6196                                    [Rania Stephan]
# 6197                                     [Gaston Velle]
# 6198                                                NaN
# 6199                                  [Ferdinand Zecca]
#
# [6200 rows x 22 columns]

# %%
movies = movies.merge(writers_df, left_on='imdb_id', right_on='tconst', how='left').drop(columns='tconst')
movies
# Out:
#                          backdrop_path      id    imdb_id original_language  \
# 0     /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg    8773  tt0055747                fr
# 1     /s9rWmLANsVlSV4XmuC0IUcseGzO.jpg     108  tt0108394                fr
# 2     /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg     109  tt0111507                fr
# 3     /A9IY3j3Hwf4Q8Q9w5QxSQPYSvCu.jpg     110  tt0111495                fr
# 4     /63HcRYJI4LKeo8sINlL71ZtlUFY.jpg     147  tt0053198                fr
# ...                                ...     ...        ...               ...
# 6195                               NaN  228590  tt0197505                fr
# 6196                               NaN  228655  tt2007418                fr
# 6197                               NaN  231154  tt1982764                fr
# 6198                               NaN  232151  tt0268168                fr
# 6199  /iPLw9xWQPXAJLppcwus5BdlCUlr.jpg  232709  tt0000495                fr
#
#                             original_title  \
# 0                      L'Amour à vingt ans
# 1                    Trois couleurs : Bleu
# 2                   Trois couleurs : Blanc
# 3                   Trois couleurs : Rouge
# 4                   Les Quatre Cents Coups
# ...                                    ...
# 6195                                  Gala
# 6196  Les trois disparitions de Soad Hosni
# 6197                  Le repas fantastique
# 6198          Le bain des dames de la cour
# 6199                  Le pêcheur de perles
#
#                                                overview  \
# 0     Love at Twenty unites five directors from five...
# 1     Julie is haunted by her grief after living thr...
# 2     Polish immigrant Karol Karol finds himself out...
# 3     Valentine, a student model in Geneva, struggle...
# 4     For young Parisian boy Antoine Doinel, life is...
# ...                                                 ...
# 6195  Gala (1961), a more polished version of Pourvu...
# 6196  This haunting and beautifully formed documenta...
# 6197  A gentleman having lunch at a hostelry experie...
# 6198  Through an invisible keyhole, the viewer peeps...
# 6199  Captivated by a vision of beckoning women, a m...
#
#                            poster_path release_date  runtime  \
# 0     /aup2QCYCsyEeQfpboXy0f4uj8aE.jpg   1962-06-22      110
# 1     /33wsWxzsNstI8N7dvuwzFmj1qBd.jpg   1993-08-01       98
# 2     /fdIet3NSa27gobMbaUml66oCQNT.jpg   1994-01-26       92
# 3      /JHmsBiX1tjCKqAul1lzC20WcAW.jpg   1994-05-12      100
# 4     /12PuU23kkDLvTd0nb8hMlE3oShB.jpg   1959-06-03       99
# ...                                ...          ...      ...
# 6195  /fZ6jgGNN5gVDVn3M7F0QP5spfuP.jpg   1961-01-01       20
# 6196  /ttVoObIPbqBflOguONw9Dm6w1qa.jpg   2011-07-10       70
# 6197  /uD8Bgyo3kIaUHUUPU5PgMsZY4Wv.jpg   1903-01-18        2
# 6198  /vBXTVwKN0FmCzW8R1gvnJCqnmM3.jpg   1904-10-01        1
# 6199  /lK0sWgOVkzhmGhzT652wdR2l33G.jpg   1907-11-03       12
#
#                                        title  ...  year  decade  \
# 0                             Love at Twenty  ...  1962    1960
# 1                         Three Colors: Blue  ...  1993    1990
# 2                        Three Colors: White  ...  1994    1990
# 3                          Three Colors: Red  ...  1994    1990
# 4                              The 400 Blows  ...  1959    1950
# ...                                      ...  ...   ...     ...
# 6195                                    Gala  ...  1961    1960
# 6196  The Three Disappearances of Soad Hosni  ...  2011    2010
# 6197                    Le repas fantastique  ...  1903    1900
# 6198                    Court Ladies Bathing  ...  1904    1900
# 6199                     The Pearl Fisherman  ...  1907    1900
#
#                           genres_list  \
# 0                ['Drama', 'Romance']
# 1                           ['Drama']
# 2      ['Comedy', 'Drama', 'Mystery']
# 3     ['Drama', 'Mystery', 'Romance']
# 4                           ['Drama']
# ...                               ...
# 6195                               []
# 6196                  ['Documentary']
# 6197            ['Comedy', 'Fantasy']
# 6198                               []
# 6199                      ['Fantasy']
#
#                          production_companies_name_list  \
# 0     ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 1     ['France 3 Cinéma', 'CED Productions', 'Miramax']
# 2     ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 3     ['Zespół Filmowy TOR', 'Le Studio Canal+', 'Fr...
# 4        ['Les Films du Carrosse', 'Sédif Productions']
# ...                                                 ...
# 6195                                                 []
# 6196    ['Joun Films', 'Sharjah Art Foundation', 'CNC']
# 6197                                ['Société Lumière']
# 6198                                   ['Pathé Frères']
# 6199                                   ['Pathé Frères']
#
#            production_countries_list       production_companies_country_list  \
# 0     ['DE', 'FR', 'IT', 'JP', 'PL']  ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']
# 1                 ['FR', 'PL', 'CH']                        ['FR', '', 'US']
# 2                       ['FR', 'PL']                ['FR', 'FR', 'FR', 'US']
# 3                 ['FR', 'PL', 'CH']                ['PL', 'FR', 'FR', 'CH']
# 4                             ['FR']                            ['FR', 'FR']
# ...                              ...                                     ...
# 6195                              []                                      []
# 6196              ['FR', 'LB', 'AE']                                      []
# 6197                          ['FR']                                      []
# 6198                          ['FR']                                      []
# 6199                          ['FR']                                      []
#
#                spoken_languages_list  \
# 0     ['it', 'ja', 'pl', 'fr', 'de']
# 1                       ['fr', 'pl']
# 2                 ['fr', 'hu', 'pl']
# 3                             ['fr']
# 4                       ['en', 'fr']
# ...                              ...
# 6195                              []
# 6196              ['ar', 'en', 'fr']
# 6197                          ['xx']
# 6198                          ['xx']
# 6199                          ['xx']
#
#                                              actor_list  \
# 0     [Marie-France Pisier, Eleonora Rossi Drago, Ch...
# 1     [Florence Pernel, Hugues Quester, Benoît Régen...
# 2     [Cezary Pazura, Jerzy Nowak, Zbigniew Zamachow...
# 3     [Jean Schlegel, Elzbieta Jasinska, Samuel Le B...
# 4     [Albert Rémy, Richard Kanayan, Daniel Couturie...
# ...                                                 ...
# 6195  [Claude Melki, Gésip Légitimus, Dolly Bell, Ge...
# 6196                                                NaN
# 6197                                                NaN
# 6198                                                NaN
# 6199                                                NaN
#
#                                          director_names  \
# 0     [François Truffaut, Marcel Ophüls, Shintarô Is...
# 1                                [Krzysztof Kieslowski]
# 2                                [Krzysztof Kieslowski]
# 3                                [Krzysztof Kieslowski]
# 4                                   [François Truffaut]
# ...                                                 ...
# 6195                               [Jean-Daniel Pollet]
# 6196                                    [Rania Stephan]
# 6197                                     [Gaston Velle]
# 6198                                                NaN
# 6199                                  [Ferdinand Zecca]
#
#                                            writer_names
# 0     [François Truffaut, Shintarô Ishihara, Marcel ...
# 1     [Krzysztof Kieslowski, Agnieszka Holland, Slaw...
# 2     [Krzysztof Kieslowski, Agnieszka Holland, Edwa...
# 3     [Krzysztof Kieslowski, Agnieszka Holland, Edwa...
# 4                    [François Truffaut, Marcel Moussy]
# ...                                                 ...
# 6195                               [Jean-Daniel Pollet]
# 6196                                    [Rania Stephan]
# 6197                                                NaN
# 6198                                                NaN
# 6199                                                NaN
#
# [6200 rows x 23 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6200 entries, 0 to 6199
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   backdrop_path                      4676 non-null   object
#  1   id                                 6200 non-null   int64
#  2   imdb_id                            6200 non-null   object
#  3   original_language                  6200 non-null   object
#  4   original_title                     6200 non-null   object
#  5   overview                           6200 non-null   object
#  6   poster_path                        6200 non-null   object
#  7   release_date                       6200 non-null   object
#  8   runtime                            6200 non-null   int64
#  9   title                              6200 non-null   object
#  10  video                              6200 non-null   bool
#  11  vote_average                       6200 non-null   float64
#  12  vote_count                         6200 non-null   int64
#  13  year                               6200 non-null   int64
#  14  decade                             6200 non-null   int64
#  15  genres_list                        6200 non-null   object
#  16  production_companies_name_list     6200 non-null   object
#  17  production_countries_list          6200 non-null   object
#  18  production_companies_country_list  6200 non-null   object
#  19  spoken_languages_list              6200 non-null   object
#  20  actor_list                         5273 non-null   object
#  21  director_names                     6173 non-null   object
#  22  writer_names                       5617 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(16)
# memory usage: 1.0+ MB

# %%
from cinema_de_la_cite.data.save_dataframe_to_csv import save_dataframe_clean
save_dataframe_clean(movies, "tmdb_processed.csv", project_root)
